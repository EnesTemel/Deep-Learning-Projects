# %%
import numpy as np 
D=np.random.randn(1000,500)
hidden_layer_sizes=[500]*10
nonlinearities=['relu']*len(hidden_layer_sizes)
import matplotlib.pyplot as plt 

act={'relu' : lambda x: np.maximum(0,x), 'tanh': lambda x : np.tanh(x)}
Hs={}
for i in range(len(hidden_layer_sizes)):
    X = D if i==0 else Hs[i-1] #input at this layer
    fan_in = X.shape[1]
    fan_out=hidden_layer_sizes[i]
    W=np.random.randn(fan_in,fan_out) / np.sqrt(fan_in/2)

    H= np.dot(X,W)
    H=act[nonlinearities[i]](H)
    Hs[i]=H
# Look at distributions at each layer
print('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
    print('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))


#plot the means and std dev

plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(),layer_means,'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(),layer_stds,'or-')
plt.title('layer std')

# plot the raw distributions

plt.figure(figsize=(15,15))
for i,H in Hs.items():
    plt.subplot(1,len(Hs),i+1)
    plt.hist(H.ravel(),30,range=(-1,1),color='purple')
# Out:
# input layer had mean -0.001845 and std 0.999946
# hidden layer 1 had mean 0.564674 and std 0.825531
# hidden layer 2 had mean 0.575813 and std 0.841651
# hidden layer 3 had mean 0.575559 and std 0.830216
# hidden layer 4 had mean 0.551944 and std 0.839991
# hidden layer 5 had mean 0.569783 and std 0.833487
# hidden layer 6 had mean 0.568638 and std 0.829583
# hidden layer 7 had mean 0.542336 and std 0.824809
# hidden layer 8 had mean 0.513113 and std 0.768117
# hidden layer 9 had mean 0.501264 and std 0.746248
# hidden layer 10 had mean 0.449193 and std 0.713714

# %%
import random

# Generate a random number uniformly distributed between -5 and 5
random_value = random.uniform(-5, 5)
10**random_value
# Out:
# 1.943326636347648e-05

# %%
10**-3
# Out:
# 0.001
